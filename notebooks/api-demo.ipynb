# %%
from fluvial_particle.RiverGrid import RiverGrid
from fluvial_particle.Particles import Particles
import h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation
from vtk.util import numpy_support
from IPython.display import Video

# %%
# Set simulation parameters
output_directory = "../tests/test"
file_name_2d = "../tests/data/Result_FM_MEander_1_long_2D1.vtk"
file_name_3d = "../tests/data/Result_FM_MEander_1_long_3D1_new.vtk"
endtime = 1460.0
dt = 0.25
PrintAtTick = 10.0
track3d = 1
nparticles = 1000
xstart, ystart, zstart = (6.14, 9.09, 10.3)
lev = 0.00025

# Pre-compute simulation times
times = np.arange(dt, endtime + dt, dt)
n_times = times.size
print_inc = np.max([np.int32(PrintAtTick / dt), 1])  # bound below
print_inc = np.min([print_inc, n_times])  # bound above
print_times = times[print_inc - 1 : n_times : print_inc]
if print_times[-1] != times[-1]:
    # add final time to print_times if not already
    print_times = np.append(print_times, times[-1])
n_prints = print_times.size + 1  # plus one so we can write t=0 to file

# %%
# Initialize river mesh
river = RiverGrid(track3d, file_name_2d, file_name_3d)

# %%
# Initialize particles
rng = np.random.default_rng(seed=12345)
x = np.full((nparticles,), fill_value=xstart)
y = np.full((nparticles,), fill_value=ystart)
z = np.full((nparticles,), fill_value=zstart)
particles = Particles(nparticles, x, y, z, rng, river, Track3D=track3d, lev=lev)

# %%
# Validate initial positions of the particles
particles.initial_validation(starttime=0.0)

# %%
# Create output particles HDF5 file
fname = output_directory + "//particles.h5"
parts_h5 = particles.create_hdf5(n_prints, nparticles, fname=fname)
particles.write_hdf5(parts_h5, 0, 0, nparticles, 0.0, 0)  # write initial condition

# %%
# Move the particles
for i in range(n_times):
    particles.move(times[i], dt)
    tidx = np.searchsorted(print_times, times[i])
    if print_times[tidx] == times[i]:
        # Write to file at specified times
        particles.write_hdf5(parts_h5, np.int32(i / print_inc) + 1, 0, nparticles, times[i], 0)
        print(f"Elapsed simulation time: {times[i]} seconds")

parts_h5.close()  # always close the HDF5 file!
# Out:
# Elapsed simulation time: 10.0 seconds
# Elapsed simulation time: 20.0 seconds
# Elapsed simulation time: 30.0 seconds
# Elapsed simulation time: 40.0 seconds
# Elapsed simulation time: 50.0 seconds
# Elapsed simulation time: 60.0 seconds
# Elapsed simulation time: 70.0 seconds
# Elapsed simulation time: 80.0 seconds
# Elapsed simulation time: 90.0 seconds
# Elapsed simulation time: 100.0 seconds
# Elapsed simulation time: 110.0 seconds
# Elapsed simulation time: 120.0 seconds
# Elapsed simulation time: 130.0 seconds
# Elapsed simulation time: 140.0 seconds
# Elapsed simulation time: 150.0 seconds
# Elapsed simulation time: 160.0 seconds
# Elapsed simulation time: 170.0 seconds
# Elapsed simulation time: 180.0 seconds
# Elapsed simulation time: 190.0 seconds
# Elapsed simulation time: 200.0 seconds
# Elapsed simulation time: 210.0 seconds
# Elapsed simulation time: 220.0 seconds
# Elapsed simulation time: 230.0 seconds
# Elapsed simulation time: 240.0 seconds
# Elapsed simulation time: 250.0 seconds
# Elapsed simulation time: 260.0 seconds
# Elapsed simulation time: 270.0 seconds
# Elapsed simulation time: 1030.0 seconds
# Elapsed simulation time: 1040.0 seconds
# Elapsed simulation time: 1050.0 seconds
# Elapsed simulation time: 1060.0 seconds
# Elapsed simulation time: 1070.0 seconds
# Elapsed simulation time: 1080.0 seconds
# Elapsed simulation time: 1090.0 seconds
# Elapsed simulation time: 1100.0 seconds
# Elapsed simulation time: 1110.0 seconds
# Elapsed simulation time: 1120.0 seconds
# Elapsed simulation time: 1130.0 seconds
# Elapsed simulation time: 1140.0 seconds
# Elapsed simulation time: 1150.0 seconds
# Elapsed simulation time: 1160.0 seconds
# Elapsed simulation time: 1170.0 seconds
# Elapsed simulation time: 1180.0 seconds
# Elapsed simulation time: 1190.0 seconds
# Elapsed simulation time: 1200.0 seconds
# Elapsed simulation time: 1210.0 seconds
# Elapsed simulation time: 1220.0 seconds
# Elapsed simulation time: 1230.0 seconds
# Elapsed simulation time: 1240.0 seconds
# Elapsed simulation time: 1250.0 seconds
# Elapsed simulation time: 1260.0 seconds
# Elapsed simulation time: 1270.0 seconds
# Elapsed simulation time: 1280.0 seconds
# Elapsed simulation time: 1290.0 seconds
# Elapsed simulation time: 1300.0 seconds
# Elapsed simulation time: 1310.0 seconds
# Elapsed simulation time: 1320.0 seconds
# Elapsed simulation time: 1330.0 seconds
# Elapsed simulation time: 1340.0 seconds
# Elapsed simulation time: 1350.0 seconds
# Elapsed simulation time: 1360.0 seconds
# Elapsed simulation time: 1370.0 seconds
# Elapsed simulation time: 1380.0 seconds
# Elapsed simulation time: 1390.0 seconds
# Elapsed simulation time: 1400.0 seconds
# Elapsed simulation time: 1410.0 seconds
# Elapsed simulation time: 1420.0 seconds
# Elapsed simulation time: 1430.0 seconds
# Elapsed simulation time: 1440.0 seconds
# Elapsed simulation time: 1450.0 seconds
# Elapsed simulation time: 1460.0 seconds

# %%
def _animate(h5fname, mvname, **ani_kwargs):
    h5f = h5py.File(h5fname, "r")
    grp = h5f["coordinates"]
    hx = grp["x"]
    hy = grp["y"]
    times = grp["time"]
    hh = h5f["properties"]["htabvbed"]

    fig, ax = plt.subplots(figsize=(10.,2.5), subplot_kw={"aspect":"equal"})
    gr = ax.scatter(xgrid, ygrid)
    sc = ax.scatter(hx[0,:], hy[0,:], s=2)

    def animate(i):
        ax.set_title(f"Simulation time: {times[i].item()}")
        sc.set_offsets(np.c_[hx[i,:], hy[i,:]])

    ani = matplotlib.animation.FuncAnimation(fig, animate, **ani_kwargs)

    plt.close()
    ani.save(mvname, dpi=100)
    h5f.close()

fname = output_directory + "//particles.h5"
mvname = output_directory + "//test.mp4"
ani_kwargs = {"interval": 100}

vtkcoords = river.vtksgrid2d.GetPoints().GetData()
coords = numpy_support.vtk_to_numpy(vtkcoords)
xgrid = coords[:, 0]
ygrid = coords[:, 1]

_animate(fname, mvname, **ani_kwargs)

Video(mvname, html_attributes="controls autoplay loop")
# Out:
# <video src="../tests/test//test.mp4" controls autoplay loop  >
#       Your browser does not support the <code>video</code> element.
#     </video>
