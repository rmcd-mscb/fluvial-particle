# %%
import h5py as h5

# %%
f = h5.File('../data/particles.h5', 'r')

# %%
list(f.keys())
# Out:
# ['coordinates', 'properties']

# %%
dset = f['coordinates']
list(dset.keys())
# Out:
# ['time', 'x', 'y', 'z']

# %%
print(dset['x'].shape)
print(type(dset['x']))
# Out:
# (181, 1000)
# <class 'h5py._hl.dataset.Dataset'>
